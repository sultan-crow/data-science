# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('athlete_events_sample.csv', encoding = 'utf-8')

df.to_excel('foo.xlsx',sheet_name='sheet1')

# %%
left = pd.DataFrame({'key': ['foo', 'bar','s'], 'lval': [1, 2,3]})
left
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
right
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2019', periods=1000))
ts=ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                     columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
df.plot()
df.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-e04caefe3ee6> in <module>
#       3 df = df.cumsum()
#       4 df.plot()
# ----> 5 df.legend(loc='best')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'legend'
